# %% [markdown]
# # UpData - História legal, agora me mostre os dados!
# Somos a UpData e começamos nossa jornada fornecendo consultoria de empresas e implementando a cultura
# data driven criando assim métricas que melhoram o marketing e faturamento da empresa.
#
# Hoje, estamos trabalhando com uma empresa chamada 'WeAvocado', uma empresa grande que existe desde 2015 e em
# 2018 nos aliamos para fornecemos nosssos serviços, tendo em vista o decrescente faturamento da empresa.

# %%
#Importando a tabela
import numpy as np
import pandas as pd

df = spark.read.csv("/FileStore/tables/avocado.csv", header=True, sep=",")
df = df.toPandas()
df.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>_c0</th>
#       <th>Date</th>
#       <th>AveragePrice</th>
#       <th>Total Volume</th>
#       <th>4046</th>
#       <th>4225</th>
#       <th>4770</th>
#       <th>Total Bags</th>
#       <th>Small Bags</th>
#       <th>Large Bags</th>
#       <th>XLarge Bags</th>
#       <th>type</th>
#       <th>year</th>
#       <th>region</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>2015-12-27</td>
#       <td>1.33</td>
#       <td>64236.62</td>
#       <td>1036.74</td>
#       <td>54454.85</td>
#       <td>48.16</td>
#       <td>8696.87</td>
#       <td>8603.62</td>
#       <td>93.25</td>
#       <td>0.0</td>
#       <td>conventional</td>
#       <td>2015</td>
#       <td>Albany</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>2015-12-20</td>
#       <td>1.35</td>
#       <td>54876.98</td>
#       <td>674.28</td>
#       <td>44638.81</td>
#       <td>58.33</td>
#       <td>9505.56</td>
#       <td>9408.07</td>
#       <td>97.49</td>
#       <td>0.0</td>
#       <td>conventional</td>
#       <td>2015</td>
#       <td>Albany</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>2015-12-13</td>
#       <td>0.93</td>
#       <td>118220.22</td>
#       <td>794.7</td>
#       <td>109149.67</td>
#       <td>130.5</td>
#       <td>8145.35</td>
#       <td>8042.21</td>
#       <td>103.14</td>
#       <td>0.0</td>
#       <td>conventional</td>
#       <td>2015</td>
#       <td>Albany</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3</td>
#       <td>2015-12-06</td>
#       <td>1.08</td>
#       <td>78992.15</td>
#       <td>1132.0</td>
#       <td>71976.41</td>
#       <td>72.58</td>
#       <td>5811.16</td>
#       <td>5677.4</td>
#       <td>133.76</td>
#       <td>0.0</td>
#       <td>conventional</td>
#       <td>2015</td>
#       <td>Albany</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4</td>
#       <td>2015-11-29</td>
#       <td>1.28</td>
#       <td>51039.6</td>
#       <td>941.48</td>
#       <td>43838.39</td>
#       <td>75.78</td>
#       <td>6183.95</td>
#       <td>5986.26</td>
#       <td>197.69</td>
#       <td>0.0</td>
#       <td>conventional</td>
#       <td>2015</td>
#       <td>Albany</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df["region"].value_counts()
# Out:
# Out[3]: Albany                 338
# Sacramento             338
# Northeast              338
# NorthernNewEngland     338
# Orlando                338
# Philadelphia           338
# PhoenixTucson          338
# Pittsburgh             338
# Plains                 338
# Portland               338
# RaleighGreensboro      338
# RichmondNorfolk        338
# Roanoke                338
# SanDiego               338
# Atlanta                338
# SanFrancisco           338
# Seattle                338
# SouthCarolina          338
# SouthCentral           338
# Southeast              338
# Spokane                338
# StLouis                338
# Syracuse               338
# Tampa                  338
# TotalUS                338
# West                   338
# NewYork                338
# NewOrleansMobile       338
# Nashville              338
# Midsouth               338
# BaltimoreWashington    338
# Boise                  338
# Boston                 338
# BuffaloRochester       338
# California             338
# Charlotte              338
# Chicago                338
# CincinnatiDayton       338
# Columbus               338
# DallasFtWorth          338
# Denver                 338
# Detroit                338
# GrandRapids            338
# GreatLakes             338
# HarrisburgScranton     338
# HartfordSpringfield    338
# Houston                338
# Indianapolis           338
# Jacksonville           338
# LasVegas               338
# LosAngeles             338
# Louisville             338
# MiamiFtLauderdale      338
# WestTexNewMexico       335
# Name: region, dtype: int64

# %%
#Conhecendo os dados
print("Shape: ", df.shape)
print("Nulos: ", df.isnull().sum())

#Deletar TotalUS
# Out:
# Shape:  (18249, 14)
# Nulos:  _c0             0
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %%
#Formatar colunas e tratar dados
df.rename(columns={'_c0': 'index'}, inplace = True)
df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>index</th>
#       <th>Date</th>
#       <th>AveragePrice</th>
#       <th>Total Volume</th>
#       <th>4046</th>
#       <th>4225</th>
#       <th>4770</th>
#       <th>Total Bags</th>
#       <th>Small Bags</th>
#       <th>Large Bags</th>
#       <th>XLarge Bags</th>
#       <th>type</th>
#       <th>year</th>
#       <th>region</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>2015-12-27</td>
#       <td>1.33</td>
#       <td>64236.62</td>
#       <td>1036.74</td>
#       <td>54454.85</td>
#       <td>48.16</td>
#       <td>8696.87</td>
#       <td>8603.62</td>
#       <td>93.25</td>
#       <td>0.0</td>
#       <td>conventional</td>
#       <td>2015</td>
#       <td>Albany</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>2015-12-20</td>
#       <td>1.35</td>
#       <td>54876.98</td>
#       <td>674.28</td>
#       <td>44638.81</td>
#       <td>58.33</td>
#       <td>9505.56</td>
#       <td>9408.07</td>
#       <td>97.49</td>
#       <td>0.0</td>
#       <td>conventional</td>
#       <td>2015</td>
#       <td>Albany</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>2015-12-13</td>
#       <td>0.93</td>
#       <td>118220.22</td>
#       <td>794.7</td>
#       <td>109149.67</td>
#       <td>130.5</td>
#       <td>8145.35</td>
#       <td>8042.21</td>
#       <td>103.14</td>
#       <td>0.0</td>
#       <td>conventional</td>
#       <td>2015</td>
#       <td>Albany</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3</td>
#       <td>2015-12-06</td>
#       <td>1.08</td>
#       <td>78992.15</td>
#       <td>1132.0</td>
#       <td>71976.41</td>
#       <td>72.58</td>
#       <td>5811.16</td>
#       <td>5677.4</td>
#       <td>133.76</td>
#       <td>0.0</td>
#       <td>conventional</td>
#       <td>2015</td>
#       <td>Albany</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4</td>
#       <td>2015-11-29</td>
#       <td>1.28</td>
#       <td>51039.6</td>
#       <td>941.48</td>
#       <td>43838.39</td>
#       <td>75.78</td>
#       <td>6183.95</td>
#       <td>5986.26</td>
#       <td>197.69</td>
#       <td>0.0</td>
#       <td>conventional</td>
#       <td>2015</td>
#       <td>Albany</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>18244</th>
#       <td>7</td>
#       <td>2018-02-04</td>
#       <td>1.63</td>
#       <td>17074.83</td>
#       <td>2046.96</td>
#       <td>1529.2</td>
#       <td>0.0</td>
#       <td>13498.67</td>
#       <td>13066.82</td>
#       <td>431.85</td>
#       <td>0.0</td>
#       <td>organic</td>
#       <td>2018</td>
#       <td>WestTexNewMexico</td>
#     </tr>
#     <tr>
#       <th>18245</th>
#       <td>8</td>
#       <td>2018-01-28</td>
#       <td>1.71</td>
#       <td>13888.04</td>
#       <td>1191.7</td>
#       <td>3431.5</td>
#       <td>0.0</td>
#       <td>9264.84</td>
#       <td>8940.04</td>
#       <td>324.8</td>
#       <td>0.0</td>
#       <td>organic</td>
#       <td>2018</td>
#       <td>WestTexNewMexico</td>
#     </tr>
#     <tr>
#       <th>18246</th>
#       <td>9</td>
#       <td>2018-01-21</td>
#       <td>1.87</td>
#       <td>13766.76</td>
#       <td>1191.92</td>
#       <td>2452.79</td>
#       <td>727.94</td>
#       <td>9394.11</td>
#       <td>9351.8</td>
#       <td>42.31</td>
#       <td>0.0</td>
#       <td>organic</td>
#       <td>2018</td>
#       <td>WestTexNewMexico</td>
#     </tr>
#     <tr>
#       <th>18247</th>
#       <td>10</td>
#       <td>2018-01-14</td>
#       <td>1.93</td>
#       <td>16205.22</td>
#       <td>1527.63</td>
#       <td>2981.04</td>
#       <td>727.01</td>
#       <td>10969.54</td>
#       <td>10919.54</td>
#       <td>50.0</td>
#       <td>0.0</td>
#       <td>organic</td>
#       <td>2018</td>
#       <td>WestTexNewMexico</td>
#     </tr>
#     <tr>
#       <th>18248</th>
#       <td>11</td>
#       <td>2018-01-07</td>
#       <td>1.62</td>
#       <td>17489.58</td>
#       <td>2894.77</td>
#       <td>2356.13</td>
#       <td>224.53</td>
#       <td>12014.15</td>
#       <td>11988.14</td>
#       <td>26.01</td>
#       <td>0.0</td>
#       <td>organic</td>
#       <td>2018</td>
#       <td>WestTexNewMexico</td>
#     </tr>
#   </tbody>
# </table>
# <p>18249 rows × 14 columns</p>
# </div>

# %%
# VENDAS POR REGIÃO

# %%
df1 = df[['Date', 'AveragePrice', 'Total Volume', 'region']]

# %%
df1.head(3)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Date</th>
#       <th>AveragePrice</th>
#       <th>Total Volume</th>
#       <th>region</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2015-12-27</td>
#       <td>1</td>
#       <td>64236</td>
#       <td>Albany</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2015-12-20</td>
#       <td>1</td>
#       <td>54876</td>
#       <td>Albany</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2015-12-13</td>
#       <td>0</td>
#       <td>118220</td>
#       <td>Albany</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df1['AveragePrice'] = df1[['AveragePrice']].astype(int)
df1['Total Volume'] = df1[['Total Volume']].astype(int)
# Out:
# <command-958745140353098>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['AveragePrice'] = df1[['AveragePrice']].astype(int)
# <command-958745140353098>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Total Volume'] = df1[['Total Volume']].astype(int)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          18249 non-null  object
#  1   AveragePrice  18249 non-null  int64
#  2   Total Volume  18249 non-null  int64
#  3   region        18249 non-null  object
# dtypes: int64(2), object(2)
# memory usage: 570.4+ KB

# %%
df2 = df1.groupby('region').sum()sort_values('Total Volume', ascending=0).head(10)

# %%
df2.sort_values('Total Volume', ascending=0).head(10)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>AveragePrice</th>
#       <th>Total Volume</th>
#     </tr>
#     <tr>
#       <th>region</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>TotalUS</th>
#       <td>289</td>
#       <td>5864740027</td>
#     </tr>
#     <tr>
#       <th>West</th>
#       <td>245</td>
#       <td>1086778994</td>
#     </tr>
#     <tr>
#       <th>California</th>
#       <td>304</td>
#       <td>1028981489</td>
#     </tr>
#     <tr>
#       <th>SouthCentral</th>
#       <td>190</td>
#       <td>1011279447</td>
#     </tr>
#     <tr>
#       <th>Northeast</th>
#       <td>367</td>
#       <td>713280743</td>
#     </tr>
#     <tr>
#       <th>Southeast</th>
#       <td>305</td>
#       <td>615238242</td>
#     </tr>
#     <tr>
#       <th>GreatLakes</th>
#       <td>314</td>
#       <td>589642388</td>
#     </tr>
#     <tr>
#       <th>Midsouth</th>
#       <td>335</td>
#       <td>508349200</td>
#     </tr>
#     <tr>
#       <th>LosAngeles</th>
#       <td>248</td>
#       <td>507896375</td>
#     </tr>
#     <tr>
#       <th>Plains</th>
#       <td>322</td>
#       <td>311188370</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df3 = df2.drop('TotalUS')

# %%
df4 = (df3.sort_values('Total Volume', ascending=0) / 1000000).head(10)

# %%
teste = df4.plot(kind='bar', stacked=1)
teste
# Out:
# Out[76]: <AxesSubplot:xlabel='region'>

# %%
# VALOR MÉDIO POR REGIÃO

# %%
dfa = df[['Date', 'AveragePrice', 'Total Volume', 'region']]

# %%
dfa['AveragePrice'] = dfa[['AveragePrice']].astype(float)
dfa['Total Volume'] = dfa[['Total Volume']].astype(float)
# Out:
# <command-2343896096371018>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfa['AveragePrice'] = dfa[['AveragePrice']].astype(float)
# <command-2343896096371018>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfa['Total Volume'] = dfa[['Total Volume']].astype(float)

# %%
dfa.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Date</th>
#       <th>AveragePrice</th>
#       <th>Total Volume</th>
#       <th>region</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2015-12-27</td>
#       <td>1.33</td>
#       <td>64236</td>
#       <td>Albany</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2015-12-20</td>
#       <td>1.35</td>
#       <td>54876</td>
#       <td>Albany</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2015-12-13</td>
#       <td>0.93</td>
#       <td>118220</td>
#       <td>Albany</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2015-12-06</td>
#       <td>1.08</td>
#       <td>78992</td>
#       <td>Albany</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2015-11-29</td>
#       <td>1.28</td>
#       <td>51039</td>
#       <td>Albany</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
dfa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          18249 non-null  object
#  1   AveragePrice  18249 non-null  float64
#  2   Total Volume  18249 non-null  int64
#  3   region        18249 non-null  object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 570.4+ KB

# %%
dfa.describe()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>AveragePrice</th>
#       <th>Total Volume</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>18249.000000</td>
#       <td>1.824900e+04</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>1.405978</td>
#       <td>8.506435e+05</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>0.402677</td>
#       <td>3.453545e+06</td>
#     </tr>
#     <tr>
#       <th>min</th>
#       <td>0.440000</td>
#       <td>8.400000e+01</td>
#     </tr>
#     <tr>
#       <th>25%</th>
#       <td>1.100000</td>
#       <td>1.083800e+04</td>
#     </tr>
#     <tr>
#       <th>50%</th>
#       <td>1.370000</td>
#       <td>1.073760e+05</td>
#     </tr>
#     <tr>
#       <th>75%</th>
#       <td>1.660000</td>
#       <td>4.329620e+05</td>
#     </tr>
#     <tr>
#       <th>max</th>
#       <td>3.250000</td>
#       <td>6.250565e+07</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
dfa['total_price'] = (dfa['AveragePrice'].round(2)) * (dfa['Total Volume'])
# Out:
# <command-2343896096371023>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfa['total_price'] = (dfa['AveragePrice'].round(2)) * (dfa['Total Volume'])

# %%
dfa.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Date</th>
#       <th>AveragePrice</th>
#       <th>Total Volume</th>
#       <th>region</th>
#       <th>total_price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2015-12-27</td>
#       <td>1.33</td>
#       <td>64236.0</td>
#       <td>Albany</td>
#       <td>85433.88</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2015-12-20</td>
#       <td>1.35</td>
#       <td>54876.0</td>
#       <td>Albany</td>
#       <td>74082.60</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2015-12-13</td>
#       <td>0.93</td>
#       <td>118220.0</td>
#       <td>Albany</td>
#       <td>109944.60</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2015-12-06</td>
#       <td>1.08</td>
#       <td>78992.0</td>
#       <td>Albany</td>
#       <td>85311.36</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2015-11-29</td>
#       <td>1.28</td>
#       <td>51039.0</td>
#       <td>Albany</td>
#       <td>65329.92</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
dfa.drop('total_price', axis=1, inplace=True)
dfa.drop('mean', axis=1, inplace=True)
# Out:
# /databricks/python/lib/python3.9/site-packages/pandas/core/frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
dfb = dfa.groupby('region').sum().sort_values('AveragePrice', ascending=0).head(10)
dfb.head(10)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>AveragePrice</th>
#       <th>Total Volume</th>
#     </tr>
#     <tr>
#       <th>region</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>HartfordSpringfield</th>
#       <td>614.70</td>
#       <td>50670376.0</td>
#     </tr>
#     <tr>
#       <th>SanFrancisco</th>
#       <td>609.82</td>
#       <td>135830029.0</td>
#     </tr>
#     <tr>
#       <th>NewYork</th>
#       <td>583.92</td>
#       <td>240733961.0</td>
#     </tr>
#     <tr>
#       <th>Philadelphia</th>
#       <td>551.66</td>
#       <td>71838629.0</td>
#     </tr>
#     <tr>
#       <th>Sacramento</th>
#       <td>548.09</td>
#       <td>75163584.0</td>
#     </tr>
#     <tr>
#       <th>Charlotte</th>
#       <td>542.84</td>
#       <td>35555383.0</td>
#     </tr>
#     <tr>
#       <th>Northeast</th>
#       <td>541.45</td>
#       <td>713280743.0</td>
#     </tr>
#     <tr>
#       <th>Albany</th>
#       <td>527.63</td>
#       <td>16067641.0</td>
#     </tr>
#     <tr>
#       <th>Chicago</th>
#       <td>526.19</td>
#       <td>133702181.0</td>
#     </tr>
#     <tr>
#       <th>RaleighGreensboro</th>
#       <td>525.63</td>
#       <td>48202561.0</td>
#     </tr>
#   </tbody>
# </table>
# </div>
